# %% [markdown]
# # 실습: Voice Conversion 모델 동작을 위한 함수 구현
#
# 본 실습의 목표는 Voice Conversion을 동작시키기 위해서 필요한 함수들을 구현하여 VC 모델을 동작시키는 것입니다. 구현이 완료된 이후에는 다양한 소스/타겟 음성을 입력하여 음성 변조 결과를 확인할 수 있습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 모델 다운로드
# 먼저 미리 학습되어 있는 VC 모델과, 목소리 정보를 추출할수 있는 모델을 다운로드 합니다.

# %%
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.9.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.4

# %%
CONFIG_SE_PATH = "config_se.json"
CHECKPOINT_SE_PATH = "SE_checkpoint.pth.tar"
# download config 
! gdown --id  19cDrhZZ0PfKf2Zhr_ebB-QASRw844Tn1 -O $CONFIG_SE_PATH
# download checkpoint  
! gdown --id   17JsW6h6TIh7-LkU2EvB_gnNrPcdBxt7X -O $CHECKPOINT_SE_PATH
# download checkpoint
! gdown --id 1sgEjHt0lbPSEw9-FSbC_mBoOPwNi87YR -O best_model.pth.tar
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19cDrhZZ0PfKf2Zhr_ebB-QASRw844Tn1
# To: /content/drive/MyDrive/SubPJT2_Voice_Conversion/config_se.json
# 100% 3.49k/3.49k [00:00<00:00, 5.46MB/s]
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=17JsW6h6TIh7-LkU2EvB_gnNrPcdBxt7X
# To: /content/drive/MyDrive/SubPJT2_Voice_Conversion/SE_checkpoint.pth.tar
# 100% 44.6M/44.6M [00:00<00:00, 172MB/s]
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1sgEjHt0lbPSEw9-FSbC_mBoOPwNi87YR
# To: /content/drive/MyDrive/SubPJT2_Voice_Conversion/best_model.pth.tar
# 100% 380M/380M [00:05<00:00, 65.4MB/s]

# %% [markdown]
# ### 라이브러리 import
# 필요한 라이브러리들을 import합니다.

# %%
# !pip install -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cython in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 1)) (0.29.33)
# Requirement already satisfied: flask in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 5)) (0.42.1)
# Collecting librosa==0.8.0
#   Downloading librosa-0.8.0.tar.gz (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (3.5.3)
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 86.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 9)) (1.3.5)
# Collecting pypinyin
#   Downloading pypinyin-0.48.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.6 MB/s eta 0:00:00
# Collecting pysbd
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 KB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 12)) (6.0)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 14)) (1.7.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 15)) (0.12.1)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 17)) (1.13.1+cu116)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 18)) (4.64.1)
# Collecting numba==0.53
#   Downloading numba-0.53.0-cp38-cp38-manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 95.4 MB/s eta 0:00:00
# Collecting umap-learn==0.5.1
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 KB 30.8 MB/s eta 0:00:00
# Collecting coqpit
#   Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Collecting mecab-python3==1.0.3
#   Downloading mecab_python3-1.0.3-cp38-cp38-manylinux1_x86_64.whl (490 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.1/490.1 KB 31.4 MB/s eta 0:00:00
# Collecting unidic-lite==1.0.8
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0
#   Downloading gruut-1.2.3.tar.gz (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 93.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec>=2021.04.0 in /usr/local/lib/python3.8/dist-packages (from -r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 28)) (2023.1.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba==0.53->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 19)) (57.4.0)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp38-cp38-manylinux2010_x86_64.whl (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 17.5 MB/s eta 0:00:00
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.8/dist-packages (from flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.8/dist-packages (from flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.8/dist-packages (from flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (3.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 9)) (2022.7.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 15)) (1.15.1)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 16)) (3.19.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.7->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 17)) (4.5.0)
# Collecting Babel~=2.8.0
#   Downloading Babel-2.8.1-py2.py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 102.0 MB/s eta 0:00:00
# Collecting gruut-ipa~=0.9.0
#   Downloading gruut-ipa-0.9.3.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Collecting num2words==0.5.10
#   Downloading num2words-0.5.10-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 KB 14.0 MB/s eta 0:00:00
# Collecting python-crfsuite~=0.9.7
#   Downloading python_crfsuite-0.9.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.2 MB/s eta 0:00:00
# Collecting gruut_lang_de~=1.2.0
#   Downloading gruut_lang_de-1.2.tar.gz (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 107.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_fr~=1.2.0
#   Downloading gruut_lang_fr-1.2.1.tar.gz (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 104.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_pt~=1.2.0
#   Downloading gruut_lang_pt-1.2.tar.gz (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 100.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_ru~=1.2.0
#   Downloading gruut_lang_ru-1.2.tar.gz (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 67.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_sv~=1.2.0
#   Downloading gruut_lang_sv-1.2.tar.gz (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 73.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_es~=1.2.0
#   Downloading gruut_lang_es-1.2.tar.gz (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 19.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_it~=1.2.0
#   Downloading gruut_lang_it-1.2.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 87.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_cs~=1.2.0
#   Downloading gruut_lang_cs-1.2.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 103.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_nl~=1.2.0
#   Downloading gruut_lang_nl-1.2.tar.gz (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 82.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 15)) (2.21)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6.0->flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=3.0->flask->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.0->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown->-r /content/drive/MyDrive/SubPJT2_Voice_Conversion/requirements.txt (line 3)) (1.7.1)
# Building wheels for collected packages: librosa, umap-learn, unidic-lite, gruut-ipa, gruut_lang_cs, gruut_lang_de, gruut_lang_es, gruut_lang_fr, gruut_lang_it, gruut_lang_nl, gruut_lang_pt, gruut_lang_ru, gruut_lang_sv, pynndescent, gruut, docopt
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201396 sha256=11c0b3858de1ec65903c09d83d842cbc416b690c302733a9176ef1749dbea21f
#   Stored in directory: /root/.cache/pip/wheels/aa/5a/92/d52f6f8560ff05a2525e6030a1903412df876714241fb76802
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76566 sha256=0f46ed3a24fa425dbc678705aeb7f9bb3032b7773025d849668681b2382a1584
#   Stored in directory: /root/.cache/pip/wheels/95/85/b7/b4b7040e49367b6d1505d7e8fb57e3e79b22fa6ac26f72520b
#   Building wheel for unidic-lite (setup.py) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658837 sha256=4b093363cd9778be0516e7fa5da5467ba891bc5d7e14e4e4e4d2b58430a6160c
#   Stored in directory: /root/.cache/pip/wheels/8c/dd/8f/e21fc192dcd38ae31e1185ce4e66e12df4e811e3d469866e15
#   Building wheel for gruut-ipa (setup.py) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.9.3-py3-none-any.whl size=39000 sha256=5735cfc01e2005aba0f878de63a2cd423a1a9baa8ab9e0c9145c8a127efdf6f4
#   Stored in directory: /root/.cache/pip/wheels/21/20/b8/bd3d771f35224e0be5d29cf1399c8d938c225eb8e30884121b
#   Building wheel for gruut_lang_cs (setup.py) ... done
#   Created wheel for gruut_lang_cs: filename=gruut_lang_cs-1.2-py3-none-any.whl size=5796596 sha256=14c9e516ca0e973c3e2a86f4c8b4c5c5a70f3f3f32c1d56a0d5ea3cfe91126a3
#   Stored in directory: /root/.cache/pip/wheels/bf/a1/66/fa31871d0dd218063ab6c7c587a3df434e664d0b03a8107d34
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-1.2-py3-none-any.whl size=9574679 sha256=0be86514c767cca352b8230bb59ee0fe863e8f90e296bee55d092347a079a14f
#   Stored in directory: /root/.cache/pip/wheels/cd/9c/ab/ce9e77e25823eef3818a70bd6bfa0e90fd080861cdd71afecf
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Created wheel for gruut_lang_es: filename=gruut_lang_es-1.2-py3-none-any.whl size=15403813 sha256=e1f3e6bcd9554db9ba38f28b18bb0bde7086f62f6e4dcb329f32fd23704fe92f
#   Stored in directory: /root/.cache/pip/wheels/b4/57/24/b196bad8290f9db370e6484a10b86453e74ba770201691aa35
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Created wheel for gruut_lang_fr: filename=gruut_lang_fr-1.2.1-py3-none-any.whl size=12103215 sha256=1cc61f6592d028255f4282f4dde47d5ae571e6b950e74ba93c651957bc0a5940
#   Stored in directory: /root/.cache/pip/wheels/c7/5e/50/67f5629e60ff109ab466168d0bfa7d4de9c89c83d10c5a7199
#   Building wheel for gruut_lang_it (setup.py) ... done
#   Created wheel for gruut_lang_it: filename=gruut_lang_it-1.2-py3-none-any.whl size=1944816 sha256=6d5fb5c0a983c1698ac404f7f4657c51710ae109c1b8ba409bf1b0bd781c6c86
#   Stored in directory: /root/.cache/pip/wheels/94/b0/21/84ecfc33bc7cb24205e83f45cbcdc518043b842909a6855587
#   Building wheel for gruut_lang_nl (setup.py) ... done
#   Created wheel for gruut_lang_nl: filename=gruut_lang_nl-1.2-py3-none-any.whl size=7399312 sha256=6e3cec0eca99bb1fdd912da931ebf001501b3da310668e00e312e64ae908031f
#   Stored in directory: /root/.cache/pip/wheels/40/ab/c3/05e970e438636b4c8bc9a63a80029495aaa34802937c8e13c6
#   Building wheel for gruut_lang_pt (setup.py) ... done
#   Created wheel for gruut_lang_pt: filename=gruut_lang_pt-1.2-py3-none-any.whl size=3412233 sha256=33d19be7050140dba820a85ddd695e1567d531ec1560f7edfb1627cb14249499
#   Stored in directory: /root/.cache/pip/wheels/b6/6b/bd/b3933a6fc29df3fe44ec0f8b4fcad564d90f4bcac646f6445d
#   Building wheel for gruut_lang_ru (setup.py) ... done
#   Created wheel for gruut_lang_ru: filename=gruut_lang_ru-1.2-py3-none-any.whl size=16955789 sha256=c404d868059ba61ae3363080139cd2e68fcebfaa803a6cbdcf6d1c029fb197d3
#   Stored in directory: /root/.cache/pip/wheels/75/34/20/23aa2a2751828afde3a21ac875c7e8426bcc29bcd789dcdd3f
#   Building wheel for gruut_lang_sv (setup.py) ... done
#   Created wheel for gruut_lang_sv: filename=gruut_lang_sv-1.2-py3-none-any.whl size=2104833 sha256=d31a8bcea8385e013f400600edf33bef1dc3fd38962bdfefe507cdf11b5a6727
#   Stored in directory: /root/.cache/pip/wheels/df/6e/1d/d7cb9c9bba592561a8abd97268b4fe2b88054789296de26cd7
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=f34f8cfc709ec394ba54b5304ca2e266105729d5ce802f4d26754a1267b9e5c7
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
#   Building wheel for gruut (setup.py) ... done
#   Created wheel for gruut: filename=gruut-1.2.3-py3-none-any.whl size=11091278 sha256=aa688d4db4fd69ec6b6fb80325718835e5a43287dde02654f2a619fafef76af5
#   Stored in directory: /root/.cache/pip/wheels/da/38/87/c924d2639b51a321a697ba8ac0229d64432d47130d79ade15e
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=368d27177b871712c9216977509a29869b929a16bb7a6856fc5058df491fe7e5
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built librosa umap-learn unidic-lite gruut-ipa gruut_lang_cs gruut_lang_de gruut_lang_es gruut_lang_fr gruut_lang_it gruut_lang_nl gruut_lang_pt gruut_lang_ru gruut_lang_sv pynndescent gruut docopt
# Installing collected packages: unidic-lite, python-crfsuite, pydub, mecab-python3, gruut_lang_sv, gruut_lang_ru, gruut_lang_pt, gruut_lang_nl, gruut_lang_it, gruut_lang_fr, gruut_lang_es, gruut_lang_de, gruut_lang_cs, docopt, pysbd, pypinyin, numpy, num2words, llvmlite, jsonlines, gruut-ipa, coqpit, Babel, anyascii, tensorboardX, numba, gruut, pynndescent, librosa, umap-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.11.0
#     Uninstalling Babel-2.11.0:
#       Successfully uninstalled Babel-2.11.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# xarray-einstats 0.5.1 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# tensorflow 2.11.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jaxlib 0.4.4+cuda11.cudnn82 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jax 0.4.4 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.19.5 which is incompatible.
# cmdstanpy 1.1.0 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# Successfully installed Babel-2.8.1 anyascii-0.3.1 coqpit-0.0.17 docopt-0.6.2 gruut-1.2.3 gruut-ipa-0.9.3 gruut_lang_cs-1.2 gruut_lang_de-1.2 gruut_lang_es-1.2 gruut_lang_fr-1.2.1 gruut_lang_it-1.2 gruut_lang_nl-1.2 gruut_lang_pt-1.2 gruut_lang_ru-1.2 gruut_lang_sv-1.2 jsonlines-1.2.0 librosa-0.8.0 llvmlite-0.36.0 mecab-python3-1.0.3 num2words-0.5.10 numba-0.53.0 numpy-1.19.5 pydub-0.25.1 pynndescent-0.5.8 pypinyin-0.48.0 pysbd-0.3.4 python-crfsuite-0.9.9 tensorboardX-2.6 umap-learn-0.5.1 unidic-lite-1.0.8

# %%
import sys
TTS_PATH = "/content/drive/MyDrive/SubPJT2_Voice_Conversion/"

# add libraries into environment
sys.path.append(TTS_PATH) # set this if TTS is not installed globally
print(sys.path)
import os
import string
import time
import argparse
import json

import numpy as np
import IPython
from IPython.display import Audio

import torch

from TTS.tts.utils.synthesis import synthesis
from TTS.tts.utils.text.symbols import make_symbols, phonemes, symbols
try:
  from TTS.utils.audio import AudioProcessor
except:
  from TTS.utils.audio import AudioProcessor


from TTS.tts.models import setup_model
from TTS.config import load_config
from TTS.tts.models.vits import *

from TTS.tts.utils.speakers import SpeakerManager
from pydub import AudioSegment
import librosa
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/SubPJT2_Voice_Conversion/', '/content/drive/MyDrive/SubPJT2_Voice_Conversion/']

# %% [markdown]
# ### Voice Conversion 모델 세팅
# 미리 학습된 Voice Conversion 모델을 동작하기 위한 기본적인 세팅을 진행합니다.

# %%
cd /content/drive/MyDrive/SubPJT2_Voice_Conversion
# Out:
# /content/drive/MyDrive/SubPJT2_Voice_Conversion

# %%
# model vars 
MODEL_PATH = 'best_model.pth.tar'
CONFIG_PATH = 'config.json'
TTS_LANGUAGES = "language_ids.json"
TTS_SPEAKERS = "speakers.json"
SAMPLING_RATE=16000
USE_CUDA = torch.cuda.is_available()

# load the config
C = load_config(CONFIG_PATH)
# load the audio processor
ap = AudioProcessor(**C.audio)

speaker_embedding = None

C.model_args['d_vector_file'] = TTS_SPEAKERS
C.model_args['use_speaker_encoder_as_loss'] = False

model = setup_model(C)
model.language_manager.set_language_ids_from_file(TTS_LANGUAGES)
# print(model.language_manager.num_languages, model.embedded_language_dim)
# print(model.emb_l)
cp = torch.load(MODEL_PATH, map_location=torch.device('cpu'))
# remove speaker encoder
model_weights = cp['model'].copy()
for key in list(model_weights.keys()):
  if "speaker_encoder" in key:
    del model_weights[key]

model.load_state_dict(model_weights)
model.eval()

if USE_CUDA:
    model = model.cuda()
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:45
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:False
#  | > do_amp_to_db_mel:True
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Using model: vits
#  > Speaker manager is loaded with 6 speakers: female-en-5, female-en-5
# , female-pt-4
# , male-en-2, male-en-2
# , male-pt-3

# %% [markdown]
# ### Speaker Encoder 모델 세팅
# 미리 학습된 Speaker Encoder 모델을 동작하기 위한 기본적인 세팅을 진행합니다.

# %%
SE_speaker_manager = SpeakerManager(encoder_model_path=CHECKPOINT_SE_PATH, encoder_config_path=CONFIG_SE_PATH, use_cuda=USE_CUDA)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400

# %% [markdown]
# #실습 진행하기
#
# ## Req. 2-2:	Spectrogram을 생성하는 compute_spec() 함수 구현

# %%
import librosa

def compute_spec(ref_file):
    ################################################################################
    # TODO: Spectrogram을 생성하는 compute_spec() 함수 구현                             #
    ################################################################################

    hop_length = 256  # 전체 frame 수
    n_fft = 1024  # frame 하나당 sample 수
    win_length = 1024

    #음성 파일 로드
    sig, sr = librosa.load(ref_file, sr=16000)

    # STFT
    stft = librosa.stft(sig, n_fft = n_fft, hop_length = hop_length, win_length = win_length, window = "hann", pad_mode = "reflect")

    #절댓값 변환
    magnitude = np.abs(stft)

    #float32로 변환하고 tensor로 변환
    spec = torch.tensor(magnitude,dtype = torch.float32).unsqueeze(0)

    ################################################################################
    # TODO: Spectrogram을 생성하는 compute_spec() 함수 구현                             #
    ################################################################################
    
    return spec

# %% [markdown]
# ### Req. 2-2의 구현을 완료한 뒤 테스트 합니다.

# %%
####Req. 2-2 test 용도####
test_audio = "/content/drive/MyDrive/SubPJT2_Voice_Conversion/jupyter/source/test.wav"
test_spec = compute_spec(test_audio)
print("shape of the test spectrogram: ", test_spec.shape)
print("max value of the test spectrogram: ", test_spec.max())
print("min value of the test spectrogram: ", test_spec.min())
####Req. 2-2 test 용도####
# Out:
# shape of the test spectrogram:  torch.Size([1, 513, 376])
# max value of the test spectrogram:  tensor(157.3934)
# min value of the test spectrogram:  tensor(7.8661e-07)

# %% [markdown]
# ### Req. 2-3의 구현을 완료한 뒤 테스트 합니다.

# %%
####Req. 2-3 test 용도####
test_audio = "/content/drive/MyDrive/SubPJT2_Voice_Conversion/jupyter/source/test.wav"
test_emb = SE_speaker_manager.compute_speaker_embedding(test_audio)
print("shape of the test embedding: ", test_emb.shape)
print("max value of the test embedding: ", test_emb.max())
print("min value of the test embedding: ", test_emb.min())
####Req. 2-3 test 용도####
# Out:
# torch.Size([96161])
# torch.Size([1, 96161])
# shape of the test embedding:  torch.Size([1, 512])
# max value of the test embedding:  tensor(0.2351, device='cuda:0')
# min value of the test embedding:  tensor(-0.2167, device='cuda:0')

# %% [markdown]
# ### Req. 2-4의 구현을 완료한 뒤 테스트 합니다.

# %%
####Req. 2-4 test 용도####
test_audios = ["/content/drive/MyDrive/SubPJT2_Voice_Conversion/jupyter/source/test.wav", "/content/drive/MyDrive/SubPJT2_Voice_Conversion/jupyter/source/test2.wav"]
test_emb = SE_speaker_manager.compute_d_vector_from_clip(test_audios)
test_emb = torch.FloatTensor(test_emb).unsqueeze(0)
print("max value of the test embedding: ", test_emb.max())
print("min value of the test embedding: ", test_emb.min())
####Req. 2-4 test 용도####
# Out:
# torch.Size([96161])
# torch.Size([1, 96161])
# torch.Size([122561])
# torch.Size([1, 122561])
# max value of the test embedding:  tensor(0.1433)
# min value of the test embedding:  tensor(-0.2144)

# %%
####Req. 2-4 test 용도####
test_audios = ["/content/drive/MyDrive/SubPJT2_Voice_Conversion/jupyter/source/test2.wav"]
test_emb = SE_speaker_manager.compute_d_vector_from_clip(test_audios)
test_emb = torch.FloatTensor(test_emb).unsqueeze(0)
print("max value of the test embedding: ", test_emb.max())
print("min value of the test embedding: ", test_emb.min())
####Req. 2-4 test 용도####
# Out:
# torch.Size([122561])
# torch.Size([1, 122561])
# max value of the test embedding:  tensor(0.1345)
# min value of the test embedding:  tensor(-0.2572)

# %% [markdown]
# # Voice Conversion 모델을 동작합니다.

# %%
print("Select target speaker reference audios files:")

target_files = []

for i in range(1,4):
    
    target_files.append(f"./jupyter/source/src{i}.m4a")
# Out:
# Select target speaker reference audios files:

# %%
print("Select driving audio file:")

driving_files = []

for i in range(1,5):

    driving_files.append(f"/content/drive/MyDrive/SubPJT2_Voice_Conversion/jupyter/source/tar{i}.m4a")
# Out:
# Select driving audio file:

# %% [markdown]
# ## Req. 2-5:	소스 음성과 타켓 음성의 embedding을 추출하는 함수 구현

# %%
################################################################################
# TODO: 소스 음성과 타켓 음성의 embedding을 추출하는 함수 구현                            #
################################################################################

#target embedding

target_emb = SE_speaker_manager.compute_d_vector_from_clip(target_files)
target_emb = torch.FloatTensor(target_emb)

#source embedding

source_emb = SE_speaker_manager.compute_d_vector_from_clip(driving_files)
source_emb = torch.FloatTensor(source_emb)

################################################################################
# TODO: 소스 음성과 타켓 음성의 embedding을 추출하는 함수 구현                            #
################################################################################
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([39382])
# torch.Size([1, 39382])
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([40496])
# torch.Size([1, 40496])
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([44211])
# torch.Size([1, 44211])
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([23778])
# torch.Size([1, 23778])
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([70961])
# torch.Size([1, 70961])
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([119630])
# torch.Size([1, 119630])
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# torch.Size([36409])
# torch.Size([1, 36409])

# %%
driving_file = driving_files[0]
driving_spec = compute_spec(driving_file)
y_lengths = torch.tensor([driving_spec.size(-1)])

if USE_CUDA:
    ref_wav_voc, _, _ = model.voice_conversion(driving_spec.cuda(), y_lengths.cuda(), source_emb.cuda(), target_emb.cuda())
    ref_wav_voc = ref_wav_voc.squeeze().cpu().detach().numpy()
else:
    ref_wav_voc, _, _ = model.voice_conversion(driving_spec, y_lengths, source_emb, target_emb)
    ref_wav_voc = ref_wav_voc.squeeze().detach().numpy()

print("Target Speaker reference Audio")
IPython.display.display(Audio(target_files[2], rate=ap.sample_rate))

print("Source speaker reference Audio")
IPython.display.display(Audio(driving_files[0], rate=ap.sample_rate))

print("Play the converted audio:")
IPython.display.display(Audio(ref_wav_voc, rate=SAMPLING_RATE))
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Target Speaker reference Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Source speaker reference Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Play the converted audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Play the converted audio:")
IPython.display.display(Audio(ref_wav_voc, rate=SAMPLING_RATE))
# Out:
# Play the converted audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
driving_spec.shape
# Out:
# torch.Size([1, 513, 164])

# %%
source_emb.shape
# Out:
# torch.Size([1, 1, 512])

# %%
target_emb.shape
# Out:
# torch.Size([1, 1, 512])
